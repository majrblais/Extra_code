# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge
from sklearn.kernel_ridge import KernelRidge

from sklearn.linear_model import LinearRegression, RANSACRegressor, TheilSenRegressor
from sklearn.decomposition import PCA  # Import PCA









# Load the data
file_path = "data_all_numerical_select_reduced.xlsx"
data = pd.read_excel(file_path)

# Define columns
data_columns = [
    'OF2',
    'OF3',
    'OF4',
    'OF5',
    'OF6',
    'OF7',
    'OF8',
    'OF9',
    'OF10',
    'OF11',
    'OF12',
    'OF13',
    'OF14',
    'OF15',
    'OF16',
    'OF17',
    'OF18',
    'OF19',
    'OF20',
    'OF21',
    'OF22',
    'OF23',
    'OF24',
    'OF25',
    'OF26',
    'OF27',
    'OF28',
    'OF29',
    'OF30',
    'OF31',
    'OF32',
    'OF33',
    'OF34',
    'OF37',
    'OF38',
    'F1',
    'F2',
    'F3_1',
    'F3_2',
    'F3_3',
    'F3_4',
    'F3_5',
    'F3_6',
    'F3_7',
    'F4',
    'F5',
    'F6',
    'F7',
    'F8',
    'F9',
    'F10',
    'F11',
    'F12',
    'F13',
    'F14',
    'F15',
    'F16',
    'F17',
    'F18',
    'F19',
    'F20',
    'F21',
    'F22',
    'F23',
    'F24',
    'F25',
    'F26',
    'F27',
    'F28',
    'F29',
    'F30',
    'F31',
    'F32',
    'F33',
    'F34',
    'F35',
    'F36',
    'F37',
    'F38',
    'F39',
    'F40',
    'F41',
    'F42',
    'F43',
    'F44',
    'F45',
    'F46',
    'F47',
    'F48',
    'F49',
    'F50',
    'F51',
    'F52',
    'F53',
    'F54',
    'F55',
    'F56',
    'F57',
    'F58',
    'F59',
    'F62',
    'F63',
    'F64',
    'F65',
    'F66',
    'F67',
    'F68',
    'S1',
    'S2',
    'S3',
    'S4',
    'S5',
    'S6',
    'PC',
    'FC',
    'WRI',
    'SVT',
    'VCHWC',
    'HWCC',
    'MC',
    'PP',
    'ST',
    'SWP',
    'DP',
    'ADLM',
    'ATDO',
    'AOD'
]

results_columns = ['WS']

# Prepare data for regression
X = data[data_columns]
y = data[results_columns[0]]

pca = PCA(n_components='mle')  # Retain 95% of variance
X_pca = pca.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

param_grid = {
    'Ridge': {
        'ridge__alpha': [0.1, 0.5, 1.0],
        'ridge__solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
    },
    'DecisionTreeRegressor': {
        'decisiontreeregressor__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'decisiontreeregressor__splitter': ['best', 'random'],
        'decisiontreeregressor__min_samples_split': [1, 2, 3, 4, 5],
        'decisiontreeregressor__max_features': [0, 1, 2, 3, 'sqrt', 'log2']
    },
    'RandomForestRegressor': {
        'randomforestregressor__n_estimators': [1, 50, 100],
        'randomforestregressor__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'randomforestregressor__min_samples_split': [2 , 5,],
        'randomforestregressor__max_features': [1, 3, 'sqrt', 'log2'],
    },
    'GradientBoostingRegressor': {
        'gradientboostingregressor__loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'gradientboostingregressor__learning_rate': [0.001, 0.01, 0.1],
        'gradientboostingregressor__n_estimators': [25, 50, 100,250],
        'gradientboostingregressor__warm_start': [True, False],
    },
    'AdaBoostRegressor': {
        'adaboostregressor__n_estimators': [1, 20, 50, 100],
        'adaboostregressor__learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0, 10],
        'adaboostregressor__loss': ['linear', 'square', 'exponential']
    },
    'KNeighborsRegressor': {
        'kneighborsregressor__n_neighbors': [2, 5, 10, 25],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__algorithm': ['ball_tree', 'kd_tree', 'brute'],
        'kneighborsregressor__leaf_size': [5, 30, 50],
        'kneighborsregressor__metric': ['cityblock', 'cosine', 'euclidean', 'haversine', 'l1', 'l2', 'manhattan', 'nan_euclidean']
    },
    'MLPRegressor': {
        'mlpregressor__hidden_layer_sizes': [(50, 50, 50), (100, 100, 100), (100, 100, 100, 100),],
        'mlpregressor__activation': ['identity', 'logistic', 'tanh', 'relu'],
        'mlpregressor__solver': ['lbfgs', 'sgd', 'adam'],
        'mlpregressor__learning_rate': ['constant', 'invscaling', 'adaptive'],
    },
    'ElasticNet': {
        'elasticnet__l1_ratio': [ 0.25, 0.5, 0.75,],
        'elasticnet__fit_intercept': [True, False],
        'elasticnet__precompute': [True, False],
        'elasticnet__copy_X': [True, False],
        'elasticnet__warm_start': [True, False],
        'elasticnet__positive': [True, False],
        'elasticnet__selection': ['cyclic', 'random']
    },
    'SGDRegressor': {
        'sgdregressor__loss': ['squared_error', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'],
        'sgdregressor__penalty': ['l2', 'l1', 'elasticnet', None],
        'sgdregressor__learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
        'sgdregressor__warm_start': [True, False],

    },
    'SVR': {
        'svr__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'svr__degree': [1, 3, 5, 10],
        'svr__gamma': ['scale', 'auto', 1.0, 5.0],
        'svr__shrinking': [True, False]
    },
    'BayesianRidge': {
        'bayesianridge__alpha_1': [1e-7, 1e-6, 1e-5],
        'bayesianridge__alpha_2': [1e-7, 1e-6, 1e-5],
        'bayesianridge__lambda_1': [ 1e-7, 1e-6, 1e-5],
        'bayesianridge__lambda_2': [ 1e-7, 1e-6, 1e-5],
    },
    'KernelRidge': {
        'kernelridge__alpha': [0.00001, 0.0001, 0.001, 0.01, 0.1, 1.0],
        'kernelridge__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'kernelridge__degree': [1, 2, 3, 5, 10],
        'kernelridge__coef0': [0.0, 0.5, 1.0]
    },
    'LinearRegression': {
        'linearregression__fit_intercept': [True, False],
        'linearregression__copy_X': [True, False],
        'linearregression__positive': [True, False]
    },
    'RANSACRegressor': {
        'ransacregressor__min_samples': [None, 1, 2, 5, 10, 50],
        'ransacregressor__max_trials': [1, 10, 50, 100, 150],
        'ransacregressor__loss': ['absolute_error', 'squared_error']
    },
    'TheilSenRegressor': {
        'theilsenregressor__max_subpopulation': [1, 10, 100, 1000],
        'theilsenregressor__n_subsamples': [None, 1, 5, 10, 25],
    }
}


models = [Ridge(), DecisionTreeRegressor(), GradientBoostingRegressor(), RandomForestRegressor(),AdaBoostRegressor(), KNeighborsRegressor(), MLPRegressor(max_iter=200),ElasticNet(max_iter=1000),SGDRegressor(max_iter=1000),SVR(cache_size=1000),BayesianRidge(max_iter=1000),KernelRidge(),LinearRegression(), RANSACRegressor(), TheilSenRegressor()]

import warnings
warnings.filterwarnings("ignore")



# Train and tune hyperparameters for each model
best_models = {}

for model in models + ['TensorFlow']:  # Add TensorFlow model to the loop
    print(model)
    if model == 'TensorFlow':
        # Define the TensorFlow model
        model_tf = tf.keras.models.Sequential([
            tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(1)
        ])

        # Compile the TensorFlow model
        model_tf.compile(optimizer='adam', loss='mean_squared_error')

        # Standardize the data for TensorFlow model
        scaler_tf = StandardScaler()
        X_train_scaled_tf = scaler_tf.fit_transform(X_train)
        X_test_scaled_tf = scaler_tf.transform(X_test)

        # Train the TensorFlow model
        model_tf.fit(X_train_scaled_tf, y_train, epochs=100, batch_size=32, validation_split=0.2)

        # Evaluate the TensorFlow model
        y_pred_tf = model_tf.predict(X_test_scaled_tf)
        rmse_tf = mean_squared_error(y_test, y_pred_tf, squared=False)
        print(f"TensorFlow RMSE: {rmse_tf}")

        # Add TensorFlow model to best_models
        best_models['TensorFlow'] = model_tf
    else:
        model_name = model.__class__.__name__
        pipeline = make_pipeline(StandardScaler(), model)
        # Perform grid search for hyperparameters
        if model_name in param_grid:
            grid_search = GridSearchCV(pipeline, param_grid[model_name], cv=5, scoring='neg_mean_squared_error')
            grid_search.fit(X_train, y_train)
            best_models[model_name] = grid_search.best_estimator_
            print(f"Best hyperparameters for {model_name}: {grid_search.best_params_}")
        else:
            pipeline.fit(X_train, y_train)
            best_models[model_name] = pipeline



import os
import tensorflow as tf
import joblib

scaler_filename = "WS_scaler_tf.pkl"
joblib.dump(scaler_tf, scaler_filename)


# Directory where you want to save your models
model_directory = "WS"

# Create the directory if it doesn't exist
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

# Make predictions using the best models
for model_name, model in best_models.items():
    print(f"Model: {model_name}")

    # Make predictions
    if model_name == 'TensorFlow':
        y_pred = y_pred_tf  # Use predictions from TensorFlow model
        # Save the TensorFlow model
        model_filename = os.path.join(model_directory, f"{model_name}_model.h5")
        model.save(model_filename)
        #print(f"Model saved as {model_filename}")
    else:
        y_pred = model.predict(X_test)

        # Save the other models using joblib
        model_filename = os.path.join(model_directory, f"{model_name}_model.pkl")
        joblib.dump(model, model_filename)
        #print(f"Model saved as {model_filename}")

    # Calculate and print RMSE
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    print(f"RMSE: {rmse}")

    # Show real and predicted results for the first 5 samples
    #print("Sample predictions:")
   # for i in range(5):
    #    print(f"Sample {i+1}: Real NR = {y_test.iloc[i]}, Predicted NR = {y_pred[i]}")

    print("\n")
# Out:
# Ridge()
# Best hyperparameters for Ridge: {'ridge__alpha': 1.0, 'ridge__solver': 'saga'}
# DecisionTreeRegressor()
# Best hyperparameters for DecisionTreeRegressor: {'decisiontreeregressor__criterion': 'squared_error', 'decisiontreeregressor__max_features': 1, 'decisiontreeregressor__min_samples_split': 4, 'decisiontreeregressor__splitter': 'random'}
# GradientBoostingRegressor()
# Best hyperparameters for GradientBoostingRegressor: {'gradientboostingregressor__learning_rate': 0.1, 'gradientboostingregressor__loss': 'squared_error', 'gradientboostingregressor__n_estimators': 250, 'gradientboostingregressor__warm_start': True}
# RandomForestRegressor()
# Best hyperparameters for RandomForestRegressor: {'randomforestregressor__criterion': 'friedman_mse', 'randomforestregressor__max_features': 'sqrt', 'randomforestregressor__min_samples_split': 2, 'randomforestregressor__n_estimators': 50}
# AdaBoostRegressor()
# Best hyperparameters for AdaBoostRegressor: {'adaboostregressor__learning_rate': 1.0, 'adaboostregressor__loss': 'linear', 'adaboostregressor__n_estimators': 100}
# KNeighborsRegressor()
# Best hyperparameters for KNeighborsRegressor: {'kneighborsregressor__algorithm': 'brute', 'kneighborsregressor__leaf_size': 5, 'kneighborsregressor__metric': 'cosine', 'kneighborsregressor__n_neighbors': 25, 'kneighborsregressor__weights': 'distance'}
# MLPRegressor()
# Best hyperparameters for MLPRegressor: {'mlpregressor__activation': 'logistic', 'mlpregressor__hidden_layer_sizes': (50, 50, 50), 'mlpregressor__learning_rate': 'constant', 'mlpregressor__solver': 'lbfgs'}
# ElasticNet()
# Best hyperparameters for ElasticNet: {'elasticnet__copy_X': True, 'elasticnet__fit_intercept': True, 'elasticnet__l1_ratio': 0.25, 'elasticnet__positive': False, 'elasticnet__precompute': False, 'elasticnet__selection': 'random', 'elasticnet__warm_start': False}
# SGDRegressor()
# Best hyperparameters for SGDRegressor: {'sgdregressor__learning_rate': 'adaptive', 'sgdregressor__loss': 'huber', 'sgdregressor__penalty': 'elasticnet', 'sgdregressor__warm_start': True}
# SVR(cache_size=1000)
# Best hyperparameters for SVR: {'svr__degree': 1, 'svr__gamma': 'scale', 'svr__kernel': 'linear', 'svr__shrinking': False}
# BayesianRidge(max_iter=1000)
# Best hyperparameters for BayesianRidge: {'bayesianridge__alpha_1': 1e-07, 'bayesianridge__alpha_2': 1e-05, 'bayesianridge__lambda_1': 1e-05, 'bayesianridge__lambda_2': 1e-07}
# KernelRidge()
# Best hyperparameters for KernelRidge: {'kernelridge__alpha': 0.1, 'kernelridge__coef0': 1.0, 'kernelridge__degree': 1, 'kernelridge__kernel': 'poly'}
# LinearRegression()
# Best hyperparameters for LinearRegression: {'linearregression__copy_X': True, 'linearregression__fit_intercept': True, 'linearregression__positive': False}
# RANSACRegressor()
# Best hyperparameters for RANSACRegressor: {'ransacregressor__loss': 'absolute_error', 'ransacregressor__max_trials': 100, 'ransacregressor__min_samples': 5}
# TheilSenRegressor()
# Best hyperparameters for TheilSenRegressor: {'theilsenregressor__max_subpopulation': 1000, 'theilsenregressor__n_subsamples': None}
# TensorFlow
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 23.3352 - val_loss: 11.5343
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.8118 - val_loss: 7.6990
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3758 - val_loss: 18.0114
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2667 - val_loss: 12.1612
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9372 - val_loss: 9.2261
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0666 - val_loss: 9.6598
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7457 - val_loss: 13.1369
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4222 - val_loss: 10.7001
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2820 - val_loss: 9.8925
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4460 - val_loss: 10.1852
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8859 - val_loss: 10.5627
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6482 - val_loss: 8.3449
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1601 - val_loss: 7.6975
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8105 - val_loss: 7.9348
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5988 - val_loss: 7.6123
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5027 - val_loss: 7.1605
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3480 - val_loss: 7.6530
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3045 - val_loss: 7.3657
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1908 - val_loss: 7.7441
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1757 - val_loss: 7.7096
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1236 - val_loss: 7.8013
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0892 - val_loss: 7.6549
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0639 - val_loss: 7.5272
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0571 - val_loss: 7.2711
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0467 - val_loss: 7.3493
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0411 - val_loss: 7.3159
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0312 - val_loss: 7.4099
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0296 - val_loss: 7.4102
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0229 - val_loss: 7.3944
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237 - val_loss: 7.4500
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0149 - val_loss: 7.4523
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0125 - val_loss: 7.5363
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153 - val_loss: 7.4643
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - val_loss: 7.5594
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - val_loss: 7.4423
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - val_loss: 7.5146
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - val_loss: 7.4544
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 7.4896
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - val_loss: 7.4851
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - val_loss: 7.4686
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - val_loss: 7.4638
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 7.5243
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - val_loss: 7.4737
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 7.5242
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - val_loss: 7.4700
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - val_loss: 7.5293
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 7.5324
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - val_loss: 7.4912
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - val_loss: 7.5923
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 7.5221
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - val_loss: 7.5700
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 7.5939
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0193e-04 - val_loss: 7.5116
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 7.6045
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 7.5295
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7148e-04 - val_loss: 7.5577
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5996e-04 - val_loss: 7.6048
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4804e-04 - val_loss: 7.5494
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4423e-04 - val_loss: 7.5443
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9413e-04 - val_loss: 7.5566
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3235e-04 - val_loss: 7.5383
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2175e-04 - val_loss: 7.5986
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5769e-04 - val_loss: 7.5879
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9209e-04 - val_loss: 7.5853
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4734e-04 - val_loss: 7.5866
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0866e-04 - val_loss: 7.5907
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3724e-05 - val_loss: 7.5427
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5758e-05 - val_loss: 7.5736
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2794e-05 - val_loss: 7.5793
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2778e-05 - val_loss: 7.5670
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6456e-05 - val_loss: 7.5866
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0710e-05 - val_loss: 7.5878
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6001e-05 - val_loss: 7.5603
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2871e-05 - val_loss: 7.5897
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8854e-05 - val_loss: 7.5743
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4197e-05 - val_loss: 7.5806
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5699e-05 - val_loss: 7.5925
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2894e-05 - val_loss: 7.5796
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2902e-06 - val_loss: 7.5809
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1049e-06 - val_loss: 7.5878
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1744e-06 - val_loss: 7.5810
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9136e-06 - val_loss: 7.5819
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7096e-06 - val_loss: 7.5800
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4714e-06 - val_loss: 7.5801
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9298e-06 - val_loss: 7.5826
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4721e-06 - val_loss: 7.5800
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1340e-06 - val_loss: 7.5763
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9784e-06 - val_loss: 7.5892
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8266e-06 - val_loss: 7.5796
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8013e-06 - val_loss: 7.5793
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5644e-06 - val_loss: 7.5814
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1784e-06 - val_loss: 7.5811
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1181e-06 - val_loss: 7.5888
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4015e-06 - val_loss: 7.5794
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0701e-06 - val_loss: 7.5792
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5938e-06 - val_loss: 7.5800
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0313e-06 - val_loss: 7.5877
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0256e-06 - val_loss: 7.5837
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9298e-06 - val_loss: 7.5833
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5027e-06 - val_loss: 7.5803
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# TensorFlow RMSE: 10.981475361698914
# Model: Ridge
# RMSE: 4.463533162857565
#
#
# Model: DecisionTreeRegressor
# RMSE: 3.769559184656421
#
#
# Model: GradientBoostingRegressor
# RMSE: 1.8289168913755642
#
#
# Model: RandomForestRegressor
# RMSE: 2.4699260905896736
#
#
# Model: AdaBoostRegressor
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# RMSE: 1.9347288999067873
#
#
# Model: KNeighborsRegressor
# RMSE: 2.5676767810680814
#
#
# Model: MLPRegressor
# RMSE: 1.4401968251265855
#
#
# Model: ElasticNet
# RMSE: 2.2196443573402043
#
#
# Model: SGDRegressor
# RMSE: 2.880370013194233
#
#
# Model: SVR
# RMSE: 5.973673448454882
#
#
# Model: BayesianRidge
# RMSE: 3.271775032311624
#
#
# Model: KernelRidge
# RMSE: 3.432849644633296
#
#
# Model: LinearRegression
# RMSE: 302.25841010313803
#
#
# Model: RANSACRegressor
# RMSE: 35.5484694937987
#
#
# Model: TheilSenRegressor
# RMSE: 227.11283428149946
#
#
# Model: TensorFlow
# RMSE: 10.981475361698914

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge
from sklearn.kernel_ridge import KernelRidge

from sklearn.linear_model import LinearRegression, RANSACRegressor, TheilSenRegressor
from sklearn.decomposition import PCA  # Import PCA









# Load the data
file_path = "data_all_numerical_select_reduced.xlsx"
data = pd.read_excel(file_path)

# Define columns
data_columns = [
    'OF2',
    'OF3',
    'OF4',
    'OF5',
    'OF6',
    'OF7',
    'OF8',
    'OF9',
    'OF10',
    'OF11',
    'OF12',
    'OF13',
    'OF14',
    'OF15',
    'OF16',
    'OF17',
    'OF18',
    'OF19',
    'OF20',
    'OF21',
    'OF22',
    'OF23',
    'OF24',
    'OF25',
    'OF26',
    'OF27',
    'OF28',
    'OF29',
    'OF30',
    'OF31',
    'OF32',
    'OF33',
    'OF34',
    'OF37',
    'OF38',
    'F1',
    'F2',
    'F3_1',
    'F3_2',
    'F3_3',
    'F3_4',
    'F3_5',
    'F3_6',
    'F3_7',
    'F4',
    'F5',
    'F6',
    'F7',
    'F8',
    'F9',
    'F10',
    'F11',
    'F12',
    'F13',
    'F14',
    'F15',
    'F16',
    'F17',
    'F18',
    'F19',
    'F20',
    'F21',
    'F22',
    'F23',
    'F24',
    'F25',
    'F26',
    'F27',
    'F28',
    'F29',
    'F30',
    'F31',
    'F32',
    'F33',
    'F34',
    'F35',
    'F36',
    'F37',
    'F38',
    'F39',
    'F40',
    'F41',
    'F42',
    'F43',
    'F44',
    'F45',
    'F46',
    'F47',
    'F48',
    'F49',
    'F50',
    'F51',
    'F52',
    'F53',
    'F54',
    'F55',
    'F56',
    'F57',
    'F58',
    'F59',
    'F62',
    'F63',
    'F64',
    'F65',
    'F66',
    'F67',
    'F68',
    'S1',
    'S2',
    'S3',
    'S4',
    'S5',
    'S6',
    'PC',
    'FC',
    'WRI',
    'SVT',
    'VCHWC',
    'HWCC',
    'MC',
    'PP',
    'ST',
    'SWP',
    'DP',
    'ADLM',
    'ATDO',
    'AOD'
]

results_columns = ['SR']

# Prepare data for regression
X = data[data_columns]
y = data[results_columns[0]]

pca = PCA(n_components='mle')  # Retain 95% of variance
X_pca = pca.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

param_grid = {
    'Ridge': {
        'ridge__alpha': [0.1, 0.5, 1.0],
        'ridge__solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
    },
    'DecisionTreeRegressor': {
        'decisiontreeregressor__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'decisiontreeregressor__splitter': ['best', 'random'],
        'decisiontreeregressor__min_samples_split': [1, 2, 3, 4, 5],
        'decisiontreeregressor__max_features': [0, 1, 2, 3, 'sqrt', 'log2']
    },
    'RandomForestRegressor': {
        'randomforestregressor__n_estimators': [1, 50, 100],
        'randomforestregressor__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'randomforestregressor__min_samples_split': [2 , 5,],
        'randomforestregressor__max_features': [1, 3, 'sqrt', 'log2'],
    },
    'GradientBoostingRegressor': {
        'gradientboostingregressor__loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'gradientboostingregressor__learning_rate': [0.001, 0.01, 0.1],
        'gradientboostingregressor__n_estimators': [25, 50, 100,250],
        'gradientboostingregressor__warm_start': [True, False],
    },
    'AdaBoostRegressor': {
        'adaboostregressor__n_estimators': [1, 20, 50, 100],
        'adaboostregressor__learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0, 10],
        'adaboostregressor__loss': ['linear', 'square', 'exponential']
    },
    'KNeighborsRegressor': {
        'kneighborsregressor__n_neighbors': [2, 5, 10, 25],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__algorithm': ['ball_tree', 'kd_tree', 'brute'],
        'kneighborsregressor__leaf_size': [5, 30, 50],
        'kneighborsregressor__metric': ['cityblock', 'cosine', 'euclidean', 'haversine', 'l1', 'l2', 'manhattan', 'nan_euclidean']
    },
    'MLPRegressor': {
        'mlpregressor__hidden_layer_sizes': [(50, 50, 50), (100, 100, 100), (100, 100, 100, 100),],
        'mlpregressor__activation': ['identity', 'logistic', 'tanh', 'relu'],
        'mlpregressor__solver': ['lbfgs', 'sgd', 'adam'],
        'mlpregressor__learning_rate': ['constant', 'invscaling', 'adaptive'],
    },
    'ElasticNet': {
        'elasticnet__l1_ratio': [ 0.25, 0.5, 0.75,],
        'elasticnet__fit_intercept': [True, False],
        'elasticnet__precompute': [True, False],
        'elasticnet__copy_X': [True, False],
        'elasticnet__warm_start': [True, False],
        'elasticnet__positive': [True, False],
        'elasticnet__selection': ['cyclic', 'random']
    },
    'SGDRegressor': {
        'sgdregressor__loss': ['squared_error', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'],
        'sgdregressor__penalty': ['l2', 'l1', 'elasticnet', None],
        'sgdregressor__learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
        'sgdregressor__warm_start': [True, False],

    },
    'SVR': {
        'svr__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'svr__degree': [1, 3, 5, 10],
        'svr__gamma': ['scale', 'auto', 1.0, 5.0],
        'svr__shrinking': [True, False]
    },
    'BayesianRidge': {
        'bayesianridge__alpha_1': [1e-7, 1e-6, 1e-5],
        'bayesianridge__alpha_2': [1e-7, 1e-6, 1e-5],
        'bayesianridge__lambda_1': [ 1e-7, 1e-6, 1e-5],
        'bayesianridge__lambda_2': [ 1e-7, 1e-6, 1e-5],
    },
    'KernelRidge': {
        'kernelridge__alpha': [0.00001, 0.0001, 0.001, 0.01, 0.1, 1.0],
        'kernelridge__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'kernelridge__degree': [1, 2, 3, 5, 10],
        'kernelridge__coef0': [0.0, 0.5, 1.0]
    },
    'LinearRegression': {
        'linearregression__fit_intercept': [True, False],
        'linearregression__copy_X': [True, False],
        'linearregression__positive': [True, False]
    },
    'RANSACRegressor': {
        'ransacregressor__min_samples': [None, 1, 2, 5, 10, 50],
        'ransacregressor__max_trials': [1, 10, 50, 100, 150],
        'ransacregressor__loss': ['absolute_error', 'squared_error']
    },
    'TheilSenRegressor': {
        'theilsenregressor__max_subpopulation': [1, 10, 100, 1000],
        'theilsenregressor__n_subsamples': [None, 1, 5, 10, 25],
    }
}


models = [Ridge(), DecisionTreeRegressor(), GradientBoostingRegressor(), RandomForestRegressor(),AdaBoostRegressor(), KNeighborsRegressor(), MLPRegressor(max_iter=200),ElasticNet(max_iter=1000),SGDRegressor(max_iter=1000),SVR(cache_size=1000),BayesianRidge(max_iter=1000),KernelRidge(),LinearRegression(), RANSACRegressor(), TheilSenRegressor()]

import warnings
warnings.filterwarnings("ignore")



# Train and tune hyperparameters for each model
best_models = {}

for model in models + ['TensorFlow']:  # Add TensorFlow model to the loop
    print(model)
    if model == 'TensorFlow':
        # Define the TensorFlow model
        model_tf = tf.keras.models.Sequential([
            tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(1)
        ])

        # Compile the TensorFlow model
        model_tf.compile(optimizer='adam', loss='mean_squared_error')

        # Standardize the data for TensorFlow model
        scaler_tf = StandardScaler()
        X_train_scaled_tf = scaler_tf.fit_transform(X_train)
        X_test_scaled_tf = scaler_tf.transform(X_test)

        # Train the TensorFlow model
        model_tf.fit(X_train_scaled_tf, y_train, epochs=100, batch_size=32, validation_split=0.2)

        # Evaluate the TensorFlow model
        y_pred_tf = model_tf.predict(X_test_scaled_tf)
        rmse_tf = mean_squared_error(y_test, y_pred_tf, squared=False)
        print(f"TensorFlow RMSE: {rmse_tf}")

        # Add TensorFlow model to best_models
        best_models['TensorFlow'] = model_tf
    else:
        model_name = model.__class__.__name__
        pipeline = make_pipeline(StandardScaler(), model)
        # Perform grid search for hyperparameters
        if model_name in param_grid:
            grid_search = GridSearchCV(pipeline, param_grid[model_name], cv=5, scoring='neg_mean_squared_error')
            grid_search.fit(X_train, y_train)
            best_models[model_name] = grid_search.best_estimator_
            print(f"Best hyperparameters for {model_name}: {grid_search.best_params_}")
        else:
            pipeline.fit(X_train, y_train)
            best_models[model_name] = pipeline




scaler_filename = "SR_scaler_tf.pkl"
joblib.dump(scaler_tf, scaler_filename)

import os
import tensorflow as tf
import joblib
# Directory where you want to save your models
model_directory = "SR"

# Create the directory if it doesn't exist
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

# Make predictions using the best models
for model_name, model in best_models.items():
    print(f"Model: {model_name}")

    # Make predictions
    if model_name == 'TensorFlow':
        y_pred = y_pred_tf  # Use predictions from TensorFlow model
        # Save the TensorFlow model
        model_filename = os.path.join(model_directory, f"{model_name}_model.h5")
        model.save(model_filename)
        #print(f"Model saved as {model_filename}")
    else:
        y_pred = model.predict(X_test)

        # Save the other models using joblib
        model_filename = os.path.join(model_directory, f"{model_name}_model.pkl")
        joblib.dump(model, model_filename)
        #print(f"Model saved as {model_filename}")

    # Calculate and print RMSE
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    print(f"RMSE: {rmse}")

    # Show real and predicted results for the first 5 samples
    #print("Sample predictions:")
   # for i in range(5):
    #    print(f"Sample {i+1}: Real NR = {y_test.iloc[i]}, Predicted NR = {y_pred[i]}")

    print("\n")
# Out:
# Ridge()
# Best hyperparameters for Ridge: {'ridge__alpha': 1.0, 'ridge__solver': 'saga'}
# DecisionTreeRegressor()
# Best hyperparameters for DecisionTreeRegressor: {'decisiontreeregressor__criterion': 'absolute_error', 'decisiontreeregressor__max_features': 'sqrt', 'decisiontreeregressor__min_samples_split': 5, 'decisiontreeregressor__splitter': 'random'}
# GradientBoostingRegressor()
# Best hyperparameters for GradientBoostingRegressor: {'gradientboostingregressor__learning_rate': 0.1, 'gradientboostingregressor__loss': 'huber', 'gradientboostingregressor__n_estimators': 250, 'gradientboostingregressor__warm_start': False}
# RandomForestRegressor()
# Best hyperparameters for RandomForestRegressor: {'randomforestregressor__criterion': 'friedman_mse', 'randomforestregressor__max_features': 'sqrt', 'randomforestregressor__min_samples_split': 2, 'randomforestregressor__n_estimators': 100}
# AdaBoostRegressor()
# Best hyperparameters for AdaBoostRegressor: {'adaboostregressor__learning_rate': 1.0, 'adaboostregressor__loss': 'linear', 'adaboostregressor__n_estimators': 100}
# KNeighborsRegressor()
# Best hyperparameters for KNeighborsRegressor: {'kneighborsregressor__algorithm': 'brute', 'kneighborsregressor__leaf_size': 5, 'kneighborsregressor__metric': 'cosine', 'kneighborsregressor__n_neighbors': 25, 'kneighborsregressor__weights': 'distance'}
# MLPRegressor()
# Best hyperparameters for MLPRegressor: {'mlpregressor__activation': 'logistic', 'mlpregressor__hidden_layer_sizes': (50, 50, 50), 'mlpregressor__learning_rate': 'constant', 'mlpregressor__solver': 'lbfgs'}
# ElasticNet()
# Best hyperparameters for ElasticNet: {'elasticnet__copy_X': True, 'elasticnet__fit_intercept': True, 'elasticnet__l1_ratio': 0.25, 'elasticnet__positive': False, 'elasticnet__precompute': True, 'elasticnet__selection': 'random', 'elasticnet__warm_start': False}
# SGDRegressor()
# Best hyperparameters for SGDRegressor: {'sgdregressor__learning_rate': 'constant', 'sgdregressor__loss': 'huber', 'sgdregressor__penalty': 'l1', 'sgdregressor__warm_start': True}
# SVR(cache_size=1000)
# Best hyperparameters for SVR: {'svr__degree': 1, 'svr__gamma': 'scale', 'svr__kernel': 'linear', 'svr__shrinking': True}
# BayesianRidge(max_iter=1000)
# Best hyperparameters for BayesianRidge: {'bayesianridge__alpha_1': 1e-07, 'bayesianridge__alpha_2': 1e-05, 'bayesianridge__lambda_1': 1e-05, 'bayesianridge__lambda_2': 1e-07}
# KernelRidge()
# Best hyperparameters for KernelRidge: {'kernelridge__alpha': 1e-05, 'kernelridge__coef0': 1.0, 'kernelridge__degree': 2, 'kernelridge__kernel': 'poly'}
# LinearRegression()
# Best hyperparameters for LinearRegression: {'linearregression__copy_X': True, 'linearregression__fit_intercept': True, 'linearregression__positive': False}
# RANSACRegressor()
# Best hyperparameters for RANSACRegressor: {'ransacregressor__loss': 'squared_error', 'ransacregressor__max_trials': 100, 'ransacregressor__min_samples': 50}
# TheilSenRegressor()
# Best hyperparameters for TheilSenRegressor: {'theilsenregressor__max_subpopulation': 1000, 'theilsenregressor__n_subsamples': None}
# TensorFlow
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 27.9231 - val_loss: 13.7420
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.2730 - val_loss: 15.9397
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.2105 - val_loss: 20.3447
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.9505 - val_loss: 11.6413
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.1701 - val_loss: 11.4391
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8211 - val_loss: 12.6670
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5549 - val_loss: 15.6355
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6120 - val_loss: 15.7630
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.9454 - val_loss: 12.2320
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7730 - val_loss: 14.1152
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5033 - val_loss: 14.6869
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1339 - val_loss: 10.4644
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8757 - val_loss: 10.9982
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0754 - val_loss: 11.1190
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8279 - val_loss: 9.5330
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6800 - val_loss: 9.7117
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4929 - val_loss: 10.2473
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4299 - val_loss: 9.4936
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3734 - val_loss: 9.8046
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2629 - val_loss: 10.0222
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1851 - val_loss: 9.3713
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1784 - val_loss: 9.7642
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1438 - val_loss: 9.7605
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1013 - val_loss: 9.3814
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1027 - val_loss: 9.6502
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0560 - val_loss: 9.5187
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0768 - val_loss: 9.5122
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0576 - val_loss: 9.5120
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0378 - val_loss: 9.4980
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0422 - val_loss: 9.4448
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0392 - val_loss: 9.5297
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0260 - val_loss: 9.4129
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0244 - val_loss: 9.4551
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237 - val_loss: 9.4021
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0180 - val_loss: 9.3601
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136 - val_loss: 9.4093
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0087 - val_loss: 9.3094
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0125 - val_loss: 9.3160
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - val_loss: 9.2884
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - val_loss: 9.2829
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - val_loss: 9.3026
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050 - val_loss: 9.2638
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - val_loss: 9.3121
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - val_loss: 9.2678
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - val_loss: 9.3158
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 9.2692
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - val_loss: 9.2920
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9503e-04 - val_loss: 9.2733
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 9.2846
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7134e-04 - val_loss: 9.2742
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7871e-04 - val_loss: 9.2738
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1095e-04 - val_loss: 9.2856
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7198e-04 - val_loss: 9.2729
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9013e-04 - val_loss: 9.2907
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4684e-04 - val_loss: 9.2758
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2781e-04 - val_loss: 9.2954
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4196e-05 - val_loss: 9.2806
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7654e-05 - val_loss: 9.2879
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0330e-05 - val_loss: 9.2788
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0025e-05 - val_loss: 9.2795
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1861e-05 - val_loss: 9.2678
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1330e-05 - val_loss: 9.2713
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4320e-05 - val_loss: 9.2700
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1773e-06 - val_loss: 9.2728
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1650e-05 - val_loss: 9.2699
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.0708e-06 - val_loss: 9.2742
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9347e-06 - val_loss: 9.2709
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4258e-06 - val_loss: 9.2751
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2461e-06 - val_loss: 9.2719
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6069e-06 - val_loss: 9.2745
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8097e-06 - val_loss: 9.2709
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5873e-06 - val_loss: 9.2751
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2084e-06 - val_loss: 9.2700
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3250e-06 - val_loss: 9.2751
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3413e-06 - val_loss: 9.2710
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8472e-06 - val_loss: 9.2759
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4061e-06 - val_loss: 9.2720
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2524e-07 - val_loss: 9.2750
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0458e-06 - val_loss: 9.2712
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0414e-07 - val_loss: 9.2740
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3991e-07 - val_loss: 9.2705
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4233e-07 - val_loss: 9.2731
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0104e-06 - val_loss: 9.2703
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6180e-07 - val_loss: 9.2736
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2175e-07 - val_loss: 9.2716
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8908e-07 - val_loss: 9.2742
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2916e-07 - val_loss: 9.2721
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7265e-07 - val_loss: 9.2725
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4194e-07 - val_loss: 9.2731
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8883e-07 - val_loss: 9.2722
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3863e-07 - val_loss: 9.2731
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1593e-07 - val_loss: 9.2723
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0503e-07 - val_loss: 9.2723
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5822e-07 - val_loss: 9.2721
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5826e-07 - val_loss: 9.2727
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3916e-07 - val_loss: 9.2731
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0111e-07 - val_loss: 9.2720
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4346e-07 - val_loss: 9.2733
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7027e-07 - val_loss: 9.2720
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7252e-07 - val_loss: 9.2740
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BEB8337E20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BEB8337E20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BEB8337E20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BEB8337E20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# TensorFlow RMSE: 18.266800915905105
# Model: Ridge
# RMSE: 2.7416689134378043
#
#
# Model: DecisionTreeRegressor
# RMSE: 3.8820690426033755
#
#
# Model: GradientBoostingRegressor
# RMSE: 1.952565262079683
#
#
# Model: RandomForestRegressor
# RMSE: 2.390240991583788
#
#
# Model: AdaBoostRegressor
# RMSE: 1.7662717602904512
#
#
# Model: KNeighborsRegressor
# RMSE: 2.5483244821008255
#
#
# Model: MLPRegressor
# RMSE: 2.3380229576739384
#
#
# Model: ElasticNet
# RMSE: 2.1932454571632563
#
#
# Model: SGDRegressor
# RMSE: 2.863368512482077
#
#
# Model: SVR
# RMSE: 2.184281599358465
#
#
# Model: BayesianRidge
# RMSE: 2.5230986637158646
#
#
# Model: KernelRidge
# RMSE: 12.71682107465145
#
#
# Model: LinearRegression
# RMSE: 196.9838158074395
#
#
# Model: RANSACRegressor
# RMSE: 749.9827284514041
#
#
# Model: TheilSenRegressor
# RMSE: 86.80863812783315
#
#
# Model: TensorFlow
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# RMSE: 18.266800915905105

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge
from sklearn.kernel_ridge import KernelRidge

from sklearn.linear_model import LinearRegression, RANSACRegressor, TheilSenRegressor
from sklearn.decomposition import PCA  # Import PCA









# Load the data
file_path = "data_all_numerical_select_reduced.xlsx"
data = pd.read_excel(file_path)

# Define columns
data_columns = [
    'OF2',
    'OF3',
    'OF4',
    'OF5',
    'OF6',
    'OF7',
    'OF8',
    'OF9',
    'OF10',
    'OF11',
    'OF12',
    'OF13',
    'OF14',
    'OF15',
    'OF16',
    'OF17',
    'OF18',
    'OF19',
    'OF20',
    'OF21',
    'OF22',
    'OF23',
    'OF24',
    'OF25',
    'OF26',
    'OF27',
    'OF28',
    'OF29',
    'OF30',
    'OF31',
    'OF32',
    'OF33',
    'OF34',
    'OF37',
    'OF38',
    'F1',
    'F2',
    'F3_1',
    'F3_2',
    'F3_3',
    'F3_4',
    'F3_5',
    'F3_6',
    'F3_7',
    'F4',
    'F5',
    'F6',
    'F7',
    'F8',
    'F9',
    'F10',
    'F11',
    'F12',
    'F13',
    'F14',
    'F15',
    'F16',
    'F17',
    'F18',
    'F19',
    'F20',
    'F21',
    'F22',
    'F23',
    'F24',
    'F25',
    'F26',
    'F27',
    'F28',
    'F29',
    'F30',
    'F31',
    'F32',
    'F33',
    'F34',
    'F35',
    'F36',
    'F37',
    'F38',
    'F39',
    'F40',
    'F41',
    'F42',
    'F43',
    'F44',
    'F45',
    'F46',
    'F47',
    'F48',
    'F49',
    'F50',
    'F51',
    'F52',
    'F53',
    'F54',
    'F55',
    'F56',
    'F57',
    'F58',
    'F59',
    'F62',
    'F63',
    'F64',
    'F65',
    'F66',
    'F67',
    'F68',
    'S1',
    'S2',
    'S3',
    'S4',
    'S5',
    'S6',
    'PC',
    'FC',
    'WRI',
    'SVT',
    'VCHWC',
    'HWCC',
    'MC',
    'PP',
    'ST',
    'SWP',
    'DP',
    'ADLM',
    'ATDO',
    'AOD'
]

results_columns = ['NR']

# Prepare data for regression
X = data[data_columns]
y = data[results_columns[0]]

pca = PCA(n_components='mle')  # Retain 95% of variance
X_pca = pca.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

param_grid = {
    'Ridge': {
        'ridge__alpha': [0.1, 0.5, 1.0],
        'ridge__solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
    },
    'DecisionTreeRegressor': {
        'decisiontreeregressor__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'decisiontreeregressor__splitter': ['best', 'random'],
        'decisiontreeregressor__min_samples_split': [1, 2, 3, 4, 5],
        'decisiontreeregressor__max_features': [0, 1, 2, 3, 'sqrt', 'log2']
    },
    'RandomForestRegressor': {
        'randomforestregressor__n_estimators': [1, 50, 100],
        'randomforestregressor__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'randomforestregressor__min_samples_split': [2 , 5,],
        'randomforestregressor__max_features': [1, 3, 'sqrt', 'log2'],
    },
    'GradientBoostingRegressor': {
        'gradientboostingregressor__loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'gradientboostingregressor__learning_rate': [0.001, 0.01, 0.1],
        'gradientboostingregressor__n_estimators': [25, 50, 100,250],
        'gradientboostingregressor__warm_start': [True, False],
    },
    'AdaBoostRegressor': {
        'adaboostregressor__n_estimators': [1, 20, 50, 100],
        'adaboostregressor__learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0, 10],
        'adaboostregressor__loss': ['linear', 'square', 'exponential']
    },
    'KNeighborsRegressor': {
        'kneighborsregressor__n_neighbors': [2, 5, 10, 25],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__algorithm': ['ball_tree', 'kd_tree', 'brute'],
        'kneighborsregressor__leaf_size': [5, 30, 50],
        'kneighborsregressor__metric': ['cityblock', 'cosine', 'euclidean', 'haversine', 'l1', 'l2', 'manhattan', 'nan_euclidean']
    },
    'MLPRegressor': {
        'mlpregressor__hidden_layer_sizes': [(50, 50, 50), (100, 100, 100), (100, 100, 100, 100),],
        'mlpregressor__activation': ['identity', 'logistic', 'tanh', 'relu'],
        'mlpregressor__solver': ['lbfgs', 'sgd', 'adam'],
        'mlpregressor__learning_rate': ['constant', 'invscaling', 'adaptive'],
    },
    'ElasticNet': {
        'elasticnet__l1_ratio': [ 0.25, 0.5, 0.75,],
        'elasticnet__fit_intercept': [True, False],
        'elasticnet__precompute': [True, False],
        'elasticnet__copy_X': [True, False],
        'elasticnet__warm_start': [True, False],
        'elasticnet__positive': [True, False],
        'elasticnet__selection': ['cyclic', 'random']
    },
    'SGDRegressor': {
        'sgdregressor__loss': ['squared_error', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'],
        'sgdregressor__penalty': ['l2', 'l1', 'elasticnet', None],
        'sgdregressor__learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
        'sgdregressor__warm_start': [True, False],

    },
    'SVR': {
        'svr__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'svr__degree': [1, 3, 5, 10],
        'svr__gamma': ['scale', 'auto', 1.0, 5.0],
        'svr__shrinking': [True, False]
    },
    'BayesianRidge': {
        'bayesianridge__alpha_1': [1e-7, 1e-6, 1e-5],
        'bayesianridge__alpha_2': [1e-7, 1e-6, 1e-5],
        'bayesianridge__lambda_1': [ 1e-7, 1e-6, 1e-5],
        'bayesianridge__lambda_2': [ 1e-7, 1e-6, 1e-5],
    },
    'KernelRidge': {
        'kernelridge__alpha': [0.00001, 0.0001, 0.001, 0.01, 0.1, 1.0],
        'kernelridge__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'kernelridge__degree': [1, 2, 3, 5, 10],
        'kernelridge__coef0': [0.0, 0.5, 1.0]
    },
    'LinearRegression': {
        'linearregression__fit_intercept': [True, False],
        'linearregression__copy_X': [True, False],
        'linearregression__positive': [True, False]
    },
    'RANSACRegressor': {
        'ransacregressor__min_samples': [None, 1, 2, 5, 10, 50],
        'ransacregressor__max_trials': [1, 10, 50, 100, 150],
        'ransacregressor__loss': ['absolute_error', 'squared_error']
    },
    'TheilSenRegressor': {
        'theilsenregressor__max_subpopulation': [1, 10, 100, 1000],
        'theilsenregressor__n_subsamples': [None, 1, 5, 10, 25],
    }
}


models = [Ridge(), DecisionTreeRegressor(), GradientBoostingRegressor(), RandomForestRegressor(),AdaBoostRegressor(), KNeighborsRegressor(), MLPRegressor(max_iter=200),ElasticNet(max_iter=1000),SGDRegressor(max_iter=1000),SVR(cache_size=1000),BayesianRidge(max_iter=1000),KernelRidge(),LinearRegression(), RANSACRegressor(), TheilSenRegressor()]

import warnings
warnings.filterwarnings("ignore")



# Train and tune hyperparameters for each model
best_models = {}

for model in models + ['TensorFlow']:  # Add TensorFlow model to the loop
    print(model)
    if model == 'TensorFlow':
        # Define the TensorFlow model
        model_tf = tf.keras.models.Sequential([
            tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(1)
        ])

        # Compile the TensorFlow model
        model_tf.compile(optimizer='adam', loss='mean_squared_error')

        # Standardize the data for TensorFlow model
        scaler_tf = StandardScaler()
        X_train_scaled_tf = scaler_tf.fit_transform(X_train)
        X_test_scaled_tf = scaler_tf.transform(X_test)

        # Train the TensorFlow model
        model_tf.fit(X_train_scaled_tf, y_train, epochs=100, batch_size=32, validation_split=0.2)

        # Evaluate the TensorFlow model
        y_pred_tf = model_tf.predict(X_test_scaled_tf)
        rmse_tf = mean_squared_error(y_test, y_pred_tf, squared=False)
        print(f"TensorFlow RMSE: {rmse_tf}")

        # Add TensorFlow model to best_models
        best_models['TensorFlow'] = model_tf
    else:
        model_name = model.__class__.__name__
        pipeline = make_pipeline(StandardScaler(), model)
        # Perform grid search for hyperparameters
        if model_name in param_grid:
            grid_search = GridSearchCV(pipeline, param_grid[model_name], cv=5, scoring='neg_mean_squared_error')
            grid_search.fit(X_train, y_train)
            best_models[model_name] = grid_search.best_estimator_
            print(f"Best hyperparameters for {model_name}: {grid_search.best_params_}")
        else:
            pipeline.fit(X_train, y_train)
            best_models[model_name] = pipeline




scaler_filename = "NR_scaler_tf.pkl"
joblib.dump(scaler_tf, scaler_filename)

import os
import tensorflow as tf
import joblib
# Directory where you want to save your models
model_directory = "NR"

# Create the directory if it doesn't exist
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

# Make predictions using the best models
for model_name, model in best_models.items():
    print(f"Model: {model_name}")

    # Make predictions
    if model_name == 'TensorFlow':
        y_pred = y_pred_tf  # Use predictions from TensorFlow model
        # Save the TensorFlow model
        model_filename = os.path.join(model_directory, f"{model_name}_model.h5")
        model.save(model_filename)
        #print(f"Model saved as {model_filename}")
    else:
        y_pred = model.predict(X_test)

        # Save the other models using joblib
        model_filename = os.path.join(model_directory, f"{model_name}_model.pkl")
        joblib.dump(model, model_filename)
        #print(f"Model saved as {model_filename}")

    # Calculate and print RMSE
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    print(f"RMSE: {rmse}")

    # Show real and predicted results for the first 5 samples
    #print("Sample predictions:")
   # for i in range(5):
    #    print(f"Sample {i+1}: Real NR = {y_test.iloc[i]}, Predicted NR = {y_pred[i]}")

    print("\n")
# Out:
# Ridge()
# Best hyperparameters for Ridge: {'ridge__alpha': 1.0, 'ridge__solver': 'saga'}
# DecisionTreeRegressor()
# Best hyperparameters for DecisionTreeRegressor: {'decisiontreeregressor__criterion': 'squared_error', 'decisiontreeregressor__max_features': 'log2', 'decisiontreeregressor__min_samples_split': 2, 'decisiontreeregressor__splitter': 'best'}
# GradientBoostingRegressor()
# Best hyperparameters for GradientBoostingRegressor: {'gradientboostingregressor__learning_rate': 0.1, 'gradientboostingregressor__loss': 'squared_error', 'gradientboostingregressor__n_estimators': 100, 'gradientboostingregressor__warm_start': False}
# RandomForestRegressor()
# Best hyperparameters for RandomForestRegressor: {'randomforestregressor__criterion': 'absolute_error', 'randomforestregressor__max_features': 'sqrt', 'randomforestregressor__min_samples_split': 2, 'randomforestregressor__n_estimators': 50}
# AdaBoostRegressor()
# Best hyperparameters for AdaBoostRegressor: {'adaboostregressor__learning_rate': 1.0, 'adaboostregressor__loss': 'square', 'adaboostregressor__n_estimators': 50}
# KNeighborsRegressor()
# Best hyperparameters for KNeighborsRegressor: {'kneighborsregressor__algorithm': 'brute', 'kneighborsregressor__leaf_size': 5, 'kneighborsregressor__metric': 'cosine', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}
# MLPRegressor()
# Best hyperparameters for MLPRegressor: {'mlpregressor__activation': 'logistic', 'mlpregressor__hidden_layer_sizes': (100, 100, 100, 100), 'mlpregressor__learning_rate': 'adaptive', 'mlpregressor__solver': 'lbfgs'}
# ElasticNet()
# Best hyperparameters for ElasticNet: {'elasticnet__copy_X': False, 'elasticnet__fit_intercept': True, 'elasticnet__l1_ratio': 0.25, 'elasticnet__positive': False, 'elasticnet__precompute': False, 'elasticnet__selection': 'random', 'elasticnet__warm_start': True}
# SGDRegressor()
# Best hyperparameters for SGDRegressor: {'sgdregressor__learning_rate': 'invscaling', 'sgdregressor__loss': 'squared_error', 'sgdregressor__penalty': 'l1', 'sgdregressor__warm_start': False}
# SVR(cache_size=1000)
# Best hyperparameters for SVR: {'svr__degree': 1, 'svr__gamma': 'scale', 'svr__kernel': 'linear', 'svr__shrinking': True}
# BayesianRidge(max_iter=1000)
# Best hyperparameters for BayesianRidge: {'bayesianridge__alpha_1': 1e-07, 'bayesianridge__alpha_2': 1e-05, 'bayesianridge__lambda_1': 1e-05, 'bayesianridge__lambda_2': 1e-07}
# KernelRidge()
# Best hyperparameters for KernelRidge: {'kernelridge__alpha': 0.1, 'kernelridge__coef0': 1.0, 'kernelridge__degree': 1, 'kernelridge__kernel': 'poly'}
# LinearRegression()
# Best hyperparameters for LinearRegression: {'linearregression__copy_X': True, 'linearregression__fit_intercept': True, 'linearregression__positive': False}
# RANSACRegressor()
# Best hyperparameters for RANSACRegressor: {'ransacregressor__loss': 'squared_error', 'ransacregressor__max_trials': 1, 'ransacregressor__min_samples': 50}
# TheilSenRegressor()
# Best hyperparameters for TheilSenRegressor: {'theilsenregressor__max_subpopulation': 1000, 'theilsenregressor__n_subsamples': None}
# TensorFlow
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 36.1537 - val_loss: 19.3972
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.2280 - val_loss: 15.0992
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.9564 - val_loss: 27.4161
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.0510 - val_loss: 18.1699
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.8685 - val_loss: 15.1321
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.0276 - val_loss: 17.1937
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.1015 - val_loss: 22.3252
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.4552 - val_loss: 18.5171
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2980 - val_loss: 17.3151
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1303 - val_loss: 19.0563
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2964 - val_loss: 19.1593
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0494 - val_loss: 18.4190
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8792 - val_loss: 19.0651
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6045 - val_loss: 19.6008
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6826 - val_loss: 18.3151
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5435 - val_loss: 19.5413
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9659 - val_loss: 18.1217
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6812 - val_loss: 17.9147
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5037 - val_loss: 17.9624
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4550 - val_loss: 16.6392
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4021 - val_loss: 18.0585
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2267 - val_loss: 17.4160
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1849 - val_loss: 17.8535
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1631 - val_loss: 18.0107
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1196 - val_loss: 17.7908
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0968 - val_loss: 17.9560
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0911 - val_loss: 17.6269
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0646 - val_loss: 17.8839
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0995 - val_loss: 17.6251
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0959 - val_loss: 17.7924
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0976 - val_loss: 17.6954
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0898 - val_loss: 17.8016
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0820 - val_loss: 17.6599
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0386 - val_loss: 17.7435
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0349 - val_loss: 17.7359
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0693 - val_loss: 17.6525
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0319 - val_loss: 17.8557
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0610 - val_loss: 17.6926
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0453 - val_loss: 17.7831
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0602 - val_loss: 17.7830
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0313 - val_loss: 17.6878
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0223 - val_loss: 17.6767
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0313 - val_loss: 17.6763
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0456 - val_loss: 17.6636
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0201 - val_loss: 17.7425
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0277 - val_loss: 17.7218
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0377 - val_loss: 17.7672
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0338 - val_loss: 17.7389
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - val_loss: 17.7377
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - val_loss: 17.7475
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0205 - val_loss: 17.7528
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - val_loss: 17.7677
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - val_loss: 17.7603
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - val_loss: 17.7738
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - val_loss: 17.7908
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 17.7062
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8693e-04 - val_loss: 17.8434
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - val_loss: 17.7272
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 17.8244
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 17.8076
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7419e-04 - val_loss: 17.7868
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5936e-04 - val_loss: 17.8304
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3520e-04 - val_loss: 17.7939
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9747e-04 - val_loss: 17.7958
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1213e-04 - val_loss: 17.7778
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1422e-04 - val_loss: 17.7883
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6935e-05 - val_loss: 17.7795
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5001e-05 - val_loss: 17.7585
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2638e-05 - val_loss: 17.8064
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1845e-04 - val_loss: 17.7669
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0279e-04 - val_loss: 17.7770
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4420e-04 - val_loss: 17.7945
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2573e-05 - val_loss: 17.7518
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0392e-05 - val_loss: 17.7850
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9984e-05 - val_loss: 17.7721
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3761e-05 - val_loss: 17.7763
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1800e-05 - val_loss: 17.7839
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1074e-05 - val_loss: 17.7617
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4977e-05 - val_loss: 17.7753
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0827e-05 - val_loss: 17.7773
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7008e-06 - val_loss: 17.7759
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7815e-06 - val_loss: 17.7743
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7892e-06 - val_loss: 17.7719
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2345e-06 - val_loss: 17.7782
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0449e-06 - val_loss: 17.7781
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5088e-06 - val_loss: 17.7754
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3423e-06 - val_loss: 17.7744
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2597e-06 - val_loss: 17.7775
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6086e-07 - val_loss: 17.7744
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1513e-06 - val_loss: 17.7761
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1648e-07 - val_loss: 17.7760
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0722e-07 - val_loss: 17.7760
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3121e-07 - val_loss: 17.7783
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3373e-07 - val_loss: 17.7743
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2718e-07 - val_loss: 17.7725
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6169e-07 - val_loss: 17.7778
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0460e-06 - val_loss: 17.7731
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4066e-07 - val_loss: 17.7742
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2988e-06 - val_loss: 17.7777
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0915e-06 - val_loss: 17.7747
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# TensorFlow RMSE: 14.08778377725483
# Model: Ridge
# RMSE: 4.502786160345896
#
#
# Model: DecisionTreeRegressor
# RMSE: 5.572780414390319
#
#
# Model: GradientBoostingRegressor
# RMSE: 1.7864838431220031
#
#
# Model: RandomForestRegressor
# RMSE: 2.6335881744585308
#
#
# Model: AdaBoostRegressor
# RMSE: 2.341978272474304
#
#
# Model: KNeighborsRegressor
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# RMSE: 3.004760053671302
#
#
# Model: MLPRegressor
# RMSE: 1.769447869975285
#
#
# Model: ElasticNet
# RMSE: 2.4341424924551833
#
#
# Model: SGDRegressor
# RMSE: 4.4291122142737605
#
#
# Model: SVR
# RMSE: 6.198189104831161
#
#
# Model: BayesianRidge
# RMSE: 4.439034389572746
#
#
# Model: KernelRidge
# RMSE: 4.441067200757756
#
#
# Model: LinearRegression
# RMSE: 235.53194201784382
#
#
# Model: RANSACRegressor
# RMSE: 5.998286518312221
#
#
# Model: TheilSenRegressor
# RMSE: 183.01128895235414
#
#
# Model: TensorFlow
# RMSE: 14.08778377725483

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge
from sklearn.kernel_ridge import KernelRidge

from sklearn.linear_model import LinearRegression, RANSACRegressor, TheilSenRegressor
from sklearn.decomposition import PCA  # Import PCA









# Load the data
file_path = "data_all_numerical_select_reduced.xlsx"
data = pd.read_excel(file_path)

# Define columns
data_columns = [
    'OF2',
    'OF3',
    'OF4',
    'OF5',
    'OF6',
    'OF7',
    'OF8',
    'OF9',
    'OF10',
    'OF11',
    'OF12',
    'OF13',
    'OF14',
    'OF15',
    'OF16',
    'OF17',
    'OF18',
    'OF19',
    'OF20',
    'OF21',
    'OF22',
    'OF23',
    'OF24',
    'OF25',
    'OF26',
    'OF27',
    'OF28',
    'OF29',
    'OF30',
    'OF31',
    'OF32',
    'OF33',
    'OF34',
    'OF37',
    'OF38',
    'F1',
    'F2',
    'F3_1',
    'F3_2',
    'F3_3',
    'F3_4',
    'F3_5',
    'F3_6',
    'F3_7',
    'F4',
    'F5',
    'F6',
    'F7',
    'F8',
    'F9',
    'F10',
    'F11',
    'F12',
    'F13',
    'F14',
    'F15',
    'F16',
    'F17',
    'F18',
    'F19',
    'F20',
    'F21',
    'F22',
    'F23',
    'F24',
    'F25',
    'F26',
    'F27',
    'F28',
    'F29',
    'F30',
    'F31',
    'F32',
    'F33',
    'F34',
    'F35',
    'F36',
    'F37',
    'F38',
    'F39',
    'F40',
    'F41',
    'F42',
    'F43',
    'F44',
    'F45',
    'F46',
    'F47',
    'F48',
    'F49',
    'F50',
    'F51',
    'F52',
    'F53',
    'F54',
    'F55',
    'F56',
    'F57',
    'F58',
    'F59',
    'F62',
    'F63',
    'F64',
    'F65',
    'F66',
    'F67',
    'F68',
    'S1',
    'S2',
    'S3',
    'S4',
    'S5',
    'S6',
    'PC',
    'FC',
    'WRI',
    'SVT',
    'VCHWC',
    'HWCC',
    'MC',
    'PP',
    'ST',
    'SWP',
    'DP',
    'ADLM',
    'ATDO',
    'AOD'
]

results_columns = ['PR']

# Prepare data for regression
X = data[data_columns]
y = data[results_columns[0]]

pca = PCA(n_components='mle')  # Retain 95% of variance
X_pca = pca.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

param_grid = {
    'Ridge': {
        'ridge__alpha': [0.1, 0.5, 1.0],
        'ridge__solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
    },
    'DecisionTreeRegressor': {
        'decisiontreeregressor__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'decisiontreeregressor__splitter': ['best', 'random'],
        'decisiontreeregressor__min_samples_split': [1, 2, 3, 4, 5],
        'decisiontreeregressor__max_features': [0, 1, 2, 3, 'sqrt', 'log2']
    },
    'RandomForestRegressor': {
        'randomforestregressor__n_estimators': [1, 50, 100],
        'randomforestregressor__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'randomforestregressor__min_samples_split': [2 , 5,],
        'randomforestregressor__max_features': [1, 3, 'sqrt', 'log2'],
    },
    'GradientBoostingRegressor': {
        'gradientboostingregressor__loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'gradientboostingregressor__learning_rate': [0.001, 0.01, 0.1],
        'gradientboostingregressor__n_estimators': [25, 50, 100,250],
        'gradientboostingregressor__warm_start': [True, False],
    },
    'AdaBoostRegressor': {
        'adaboostregressor__n_estimators': [1, 20, 50, 100],
        'adaboostregressor__learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0, 10],
        'adaboostregressor__loss': ['linear', 'square', 'exponential']
    },
    'KNeighborsRegressor': {
        'kneighborsregressor__n_neighbors': [2, 5, 10, 25],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__algorithm': ['ball_tree', 'kd_tree', 'brute'],
        'kneighborsregressor__leaf_size': [5, 30, 50],
        'kneighborsregressor__metric': ['cityblock', 'cosine', 'euclidean', 'haversine', 'l1', 'l2', 'manhattan', 'nan_euclidean']
    },
    'MLPRegressor': {
        'mlpregressor__hidden_layer_sizes': [(50, 50, 50), (100, 100, 100), (100, 100, 100, 100),],
        'mlpregressor__activation': ['identity', 'logistic', 'tanh', 'relu'],
        'mlpregressor__solver': ['lbfgs', 'sgd', 'adam'],
        'mlpregressor__learning_rate': ['constant', 'invscaling', 'adaptive'],
    },
    'ElasticNet': {
        'elasticnet__l1_ratio': [ 0.25, 0.5, 0.75,],
        'elasticnet__fit_intercept': [True, False],
        'elasticnet__precompute': [True, False],
        'elasticnet__copy_X': [True, False],
        'elasticnet__warm_start': [True, False],
        'elasticnet__positive': [True, False],
        'elasticnet__selection': ['cyclic', 'random']
    },
    'SGDRegressor': {
        'sgdregressor__loss': ['squared_error', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'],
        'sgdregressor__penalty': ['l2', 'l1', 'elasticnet', None],
        'sgdregressor__learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
        'sgdregressor__warm_start': [True, False],

    },
    'SVR': {
        'svr__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'svr__degree': [1, 3, 5, 10],
        'svr__gamma': ['scale', 'auto', 1.0, 5.0],
        'svr__shrinking': [True, False]
    },
    'BayesianRidge': {
        'bayesianridge__alpha_1': [1e-7, 1e-6, 1e-5],
        'bayesianridge__alpha_2': [1e-7, 1e-6, 1e-5],
        'bayesianridge__lambda_1': [ 1e-7, 1e-6, 1e-5],
        'bayesianridge__lambda_2': [ 1e-7, 1e-6, 1e-5],
    },
    'KernelRidge': {
        'kernelridge__alpha': [0.00001, 0.0001, 0.001, 0.01, 0.1, 1.0],
        'kernelridge__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'kernelridge__degree': [1, 2, 3, 5, 10],
        'kernelridge__coef0': [0.0, 0.5, 1.0]
    },
    'LinearRegression': {
        'linearregression__fit_intercept': [True, False],
        'linearregression__copy_X': [True, False],
        'linearregression__positive': [True, False]
    },
    'RANSACRegressor': {
        'ransacregressor__min_samples': [None, 1, 2, 5, 10, 50],
        'ransacregressor__max_trials': [1, 10, 50, 100, 150],
        'ransacregressor__loss': ['absolute_error', 'squared_error']
    },
    'TheilSenRegressor': {
        'theilsenregressor__max_subpopulation': [1, 10, 100, 1000],
        'theilsenregressor__n_subsamples': [None, 1, 5, 10, 25],
    }
}


models = [Ridge(), DecisionTreeRegressor(), GradientBoostingRegressor(), RandomForestRegressor(),AdaBoostRegressor(), KNeighborsRegressor(), MLPRegressor(max_iter=200),ElasticNet(max_iter=1000),SGDRegressor(max_iter=1000),SVR(cache_size=1000),BayesianRidge(max_iter=1000),KernelRidge(),LinearRegression(), RANSACRegressor(), TheilSenRegressor()]

import warnings
warnings.filterwarnings("ignore")



# Train and tune hyperparameters for each model
best_models = {}

for model in models + ['TensorFlow']:  # Add TensorFlow model to the loop
    print(model)
    if model == 'TensorFlow':
        # Define the TensorFlow model
        model_tf = tf.keras.models.Sequential([
            tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(1)
        ])

        # Compile the TensorFlow model
        model_tf.compile(optimizer='adam', loss='mean_squared_error')

        # Standardize the data for TensorFlow model
        scaler_tf = StandardScaler()
        X_train_scaled_tf = scaler_tf.fit_transform(X_train)
        X_test_scaled_tf = scaler_tf.transform(X_test)

        # Train the TensorFlow model
        model_tf.fit(X_train_scaled_tf, y_train, epochs=100, batch_size=32, validation_split=0.2)

        # Evaluate the TensorFlow model
        y_pred_tf = model_tf.predict(X_test_scaled_tf)
        rmse_tf = mean_squared_error(y_test, y_pred_tf, squared=False)
        print(f"TensorFlow RMSE: {rmse_tf}")

        # Add TensorFlow model to best_models
        best_models['TensorFlow'] = model_tf
    else:
        model_name = model.__class__.__name__
        pipeline = make_pipeline(StandardScaler(), model)
        # Perform grid search for hyperparameters
        if model_name in param_grid:
            grid_search = GridSearchCV(pipeline, param_grid[model_name], cv=5, scoring='neg_mean_squared_error')
            grid_search.fit(X_train, y_train)
            best_models[model_name] = grid_search.best_estimator_
            print(f"Best hyperparameters for {model_name}: {grid_search.best_params_}")
        else:
            pipeline.fit(X_train, y_train)
            best_models[model_name] = pipeline




scaler_filename = "PR_scaler_tf.pkl"
joblib.dump(scaler_tf, scaler_filename)

import os
import tensorflow as tf
import joblib
# Directory where you want to save your models
model_directory = "PR"

# Create the directory if it doesn't exist
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

# Make predictions using the best models
for model_name, model in best_models.items():
    print(f"Model: {model_name}")

    # Make predictions
    if model_name == 'TensorFlow':
        y_pred = y_pred_tf  # Use predictions from TensorFlow model
        # Save the TensorFlow model
        model_filename = os.path.join(model_directory, f"{model_name}_model.h5")
        model.save(model_filename)
        #print(f"Model saved as {model_filename}")
    else:
        y_pred = model.predict(X_test)

        # Save the other models using joblib
        model_filename = os.path.join(model_directory, f"{model_name}_model.pkl")
        joblib.dump(model, model_filename)
        #print(f"Model saved as {model_filename}")

    # Calculate and print RMSE
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    print(f"RMSE: {rmse}")

    # Show real and predicted results for the first 5 samples
    #print("Sample predictions:")
   # for i in range(5):
    #    print(f"Sample {i+1}: Real NR = {y_test.iloc[i]}, Predicted NR = {y_pred[i]}")

    print("\n")
# Out:
# Ridge()
# Best hyperparameters for Ridge: {'ridge__alpha': 1.0, 'ridge__solver': 'saga'}
# DecisionTreeRegressor()
# Best hyperparameters for DecisionTreeRegressor: {'decisiontreeregressor__criterion': 'poisson', 'decisiontreeregressor__max_features': 1, 'decisiontreeregressor__min_samples_split': 4, 'decisiontreeregressor__splitter': 'best'}
# GradientBoostingRegressor()
# Best hyperparameters for GradientBoostingRegressor: {'gradientboostingregressor__learning_rate': 0.1, 'gradientboostingregressor__loss': 'squared_error', 'gradientboostingregressor__n_estimators': 250, 'gradientboostingregressor__warm_start': False}
# RandomForestRegressor()
# Best hyperparameters for RandomForestRegressor: {'randomforestregressor__criterion': 'friedman_mse', 'randomforestregressor__max_features': 'sqrt', 'randomforestregressor__min_samples_split': 2, 'randomforestregressor__n_estimators': 50}
# AdaBoostRegressor()
# Best hyperparameters for AdaBoostRegressor: {'adaboostregressor__learning_rate': 1.0, 'adaboostregressor__loss': 'square', 'adaboostregressor__n_estimators': 100}
# KNeighborsRegressor()
# Best hyperparameters for KNeighborsRegressor: {'kneighborsregressor__algorithm': 'brute', 'kneighborsregressor__leaf_size': 5, 'kneighborsregressor__metric': 'cosine', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}
# MLPRegressor()
# Best hyperparameters for MLPRegressor: {'mlpregressor__activation': 'identity', 'mlpregressor__hidden_layer_sizes': (50, 50, 50), 'mlpregressor__learning_rate': 'constant', 'mlpregressor__solver': 'sgd'}
# ElasticNet()
# Best hyperparameters for ElasticNet: {'elasticnet__copy_X': False, 'elasticnet__fit_intercept': True, 'elasticnet__l1_ratio': 0.25, 'elasticnet__positive': False, 'elasticnet__precompute': False, 'elasticnet__selection': 'random', 'elasticnet__warm_start': False}
# SGDRegressor()
# Best hyperparameters for SGDRegressor: {'sgdregressor__learning_rate': 'invscaling', 'sgdregressor__loss': 'squared_error', 'sgdregressor__penalty': 'l1', 'sgdregressor__warm_start': False}
# SVR(cache_size=1000)
# Best hyperparameters for SVR: {'svr__degree': 1, 'svr__gamma': 'scale', 'svr__kernel': 'linear', 'svr__shrinking': False}
# BayesianRidge(max_iter=1000)
# Best hyperparameters for BayesianRidge: {'bayesianridge__alpha_1': 1e-07, 'bayesianridge__alpha_2': 1e-05, 'bayesianridge__lambda_1': 1e-05, 'bayesianridge__lambda_2': 1e-07}
# KernelRidge()
# Best hyperparameters for KernelRidge: {'kernelridge__alpha': 0.1, 'kernelridge__coef0': 1.0, 'kernelridge__degree': 1, 'kernelridge__kernel': 'poly'}
# LinearRegression()
# Best hyperparameters for LinearRegression: {'linearregression__copy_X': True, 'linearregression__fit_intercept': True, 'linearregression__positive': False}
# RANSACRegressor()
# Best hyperparameters for RANSACRegressor: {'ransacregressor__loss': 'squared_error', 'ransacregressor__max_trials': 1, 'ransacregressor__min_samples': 50}
# TheilSenRegressor()
# Best hyperparameters for TheilSenRegressor: {'theilsenregressor__max_subpopulation': 1000, 'theilsenregressor__n_subsamples': None}
# TensorFlow
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 46.0391 - val_loss: 21.9395
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.2611 - val_loss: 9.7255
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.6480 - val_loss: 32.5616
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.6743 - val_loss: 12.3234
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0644 - val_loss: 8.7705
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3412 - val_loss: 9.7576
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3811 - val_loss: 16.4578
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5979 - val_loss: 15.8433
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8164 - val_loss: 10.0096
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2238 - val_loss: 9.6962
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0457 - val_loss: 14.6834
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4759 - val_loss: 13.9252
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7524 - val_loss: 10.7711
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1300 - val_loss: 12.4230
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8705 - val_loss: 13.4767
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6717 - val_loss: 11.9344
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5092 - val_loss: 11.3147
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3495 - val_loss: 12.2728
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2504 - val_loss: 11.7656
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1903 - val_loss: 11.3370
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1694 - val_loss: 11.9761
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1402 - val_loss: 11.6252
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0976 - val_loss: 11.7054
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0564 - val_loss: 11.6615
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0469 - val_loss: 11.7920
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0471 - val_loss: 11.6988
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - val_loss: 11.8692
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0256 - val_loss: 11.7623
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0197 - val_loss: 11.8214
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - val_loss: 11.7306
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0159 - val_loss: 11.7315
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090 - val_loss: 11.7502
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - val_loss: 11.7003
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - val_loss: 11.7671
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 11.7427
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - val_loss: 11.7539
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - val_loss: 11.7846
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - val_loss: 11.7251
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - val_loss: 11.7941
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - val_loss: 11.7679
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 11.7964
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 11.7825
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - val_loss: 11.7936
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 11.7840
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - val_loss: 11.7969
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 11.7795
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025 - val_loss: 11.7994
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - val_loss: 11.8035
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - val_loss: 11.8165
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7082e-04 - val_loss: 11.8164
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6376e-04 - val_loss: 11.8181
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3580e-04 - val_loss: 11.8295
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - val_loss: 11.8324
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4181e-04 - val_loss: 11.8337
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0920e-04 - val_loss: 11.8339
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9167e-04 - val_loss: 11.8242
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9177e-04 - val_loss: 11.8496
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4144e-04 - val_loss: 11.8328
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8707e-04 - val_loss: 11.8661
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7415e-04 - val_loss: 11.8501
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4762e-04 - val_loss: 11.8694
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3483e-04 - val_loss: 11.8585
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8853e-04 - val_loss: 11.8782
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0988e-04 - val_loss: 11.8637
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8482e-04 - val_loss: 11.8808
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7060e-04 - val_loss: 11.8647
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9215e-05 - val_loss: 11.8822
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2852e-05 - val_loss: 11.8696
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7329e-05 - val_loss: 11.8821
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1536e-04 - val_loss: 11.8766
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4161e-04 - val_loss: 11.8788
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8404e-05 - val_loss: 11.8841
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8172e-05 - val_loss: 11.8855
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9729e-05 - val_loss: 11.8917
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8930e-05 - val_loss: 11.8931
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2230e-05 - val_loss: 11.8930
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1701e-05 - val_loss: 11.8964
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4290e-05 - val_loss: 11.8947
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9357e-05 - val_loss: 11.8932
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3800e-05 - val_loss: 11.9015
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5410e-05 - val_loss: 11.8914
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4935e-06 - val_loss: 11.9038
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0184e-05 - val_loss: 11.8966
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2760e-06 - val_loss: 11.9013
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0914e-05 - val_loss: 11.9008
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5757e-05 - val_loss: 11.8983
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7190e-06 - val_loss: 11.9052
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0662e-06 - val_loss: 11.8996
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9329e-06 - val_loss: 11.9049
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0274e-06 - val_loss: 11.8996
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9340e-06 - val_loss: 11.9067
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0222e-06 - val_loss: 11.9032
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0153e-06 - val_loss: 11.9063
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2972e-06 - val_loss: 11.9036
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1804e-06 - val_loss: 11.9072
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3651e-07 - val_loss: 11.9055
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8244e-06 - val_loss: 11.9082
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3244e-07 - val_loss: 11.9067
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8255e-07 - val_loss: 11.9090
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9642e-07 - val_loss: 11.9076
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# TensorFlow RMSE: 15.420255381824443
# Model: Ridge
# RMSE: 6.923037540220166
#
#
# Model: DecisionTreeRegressor
# RMSE: 3.8697621424969704
#
#
# Model: GradientBoostingRegressor
# RMSE: 1.321340345396886
#
#
# Model: RandomForestRegressor
# RMSE: 2.2039303602842413
#
#
# Model: AdaBoostRegressor
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# RMSE: 1.2807909634958359
#
#
# Model: KNeighborsRegressor
# RMSE: 2.298001014830678
#
#
# Model: MLPRegressor
# RMSE: 6.117177470889234
#
#
# Model: ElasticNet
# RMSE: 3.549001453184378
#
#
# Model: SGDRegressor
# RMSE: 6.391009139931659
#
#
# Model: SVR
# RMSE: 8.839395178331733
#
#
# Model: BayesianRidge
# RMSE: 6.3694919478125795
#
#
# Model: KernelRidge
# RMSE: 6.412290432125347
#
#
# Model: LinearRegression
# RMSE: 282.72326900379227
#
#
# Model: RANSACRegressor
# RMSE: 8.270247892935153
#
#
# Model: TheilSenRegressor
# RMSE: 181.75746324270537
#
#
# Model: TensorFlow
# RMSE: 15.420255381824443

# %%
# After fitting PCA
joblib.dump(pca, 'pca_model.pkl')

# In other code
pca = joblib.load('pca_model.pkl')
